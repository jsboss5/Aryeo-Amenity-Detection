# %%
print("This is the download notebook I will use to download images!")
# Out:
# This is the download notebook I will use to download images!

# %%
print("has this update?")
# Out:
# has this update?
